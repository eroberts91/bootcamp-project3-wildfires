# %%
#dependencies
import pandas as pd

# %%
#import csv file into pandas for further cleaning
large_fires_df = pd.read_csv('data/large_fires.csv')
# Out:
# /var/folders/mc/lmqnjm2578xd0pdfn2jpsd9w0000gn/T/ipykernel_58943/3282634620.py:2: DtypeWarning: Columns (1,2,4,5,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   large_fires_df = pd.read_csv('data/large_fires.csv')

# %%
#drop all rows with incomplete data
columncleanedfires_df = large_fires_df.dropna(subset=['FIRE_SIZE_CLASS','STATE'])

#drop OBJECTID and Shape columns
finalfires_df = columncleanedfires_df.drop(columns=['OBJECTID', 'Shape'])

#reset index and drop old index
index_fires = finalfires_df.reset_index()
finalfires_df = index_fires.drop(columns=['index'])

# %%
finalfires_df
# Out:
#             FIRE_NAME  FIRE_YEAR FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0               FREDS     2004.0    7700.0               G  38.780000
# 1        AUSTIN CREEK     2005.0     125.0               D  36.001667
# 2      THOMPSON BUTTE     2005.0     119.0               D  43.899167
# 3        CHARLES DRAW     2005.0     119.0               D  43.892778
# 4               THREE     2005.0   16100.0               G  33.723333
# ...               ...        ...       ...             ...        ...
# 63512         204 COW     2019.0    9668.0               G  44.285050
# 63513          CAMERA     2020.0     401.0               E  36.303830
# 63514     22ND AVE SE     2020.0    1000.0               F  26.191111
# 63515           POWER     2020.0     100.0               D  37.148611
# 63516     TAYLOR POND     2020.0   24892.0               G  46.670340
#
#            LONGITUDE STATE
# 0            -120.26    CA
# 1             -81.59    NC
# 2      -102.95472222    SD
# 3      -102.94805556    SD
# 4           -111.275    AZ
# ...              ...   ...
# 63512      -118.4598    OR
# 63513      -94.90382    OK
# 63514    -81.5238889    FL
# 63515  -119.50305559    CA
# 63516      -120.1145    WA
#
# [63517 rows x 7 columns]
